# %%
import sage.all


R=BooleanPolynomialRing(2181,['k%d'%(i) for i in range (80)]+['u%d'%(i) for i in range (1000)]+['v%d'%(i) for i in range (1000)]+['n%d'%(i) for i in range (40)]+['l%d'%(i) for i in range (61)])
R.inject_variables()
A=[]
Nr=320
gs=45
K=[0]*80
KV=[0]*80
L = [0]*61
N = [0]*40
IL = [0]*61
NV = [0]*40
LV = [0]*61
IN = [0]*40
Z = [0]*1000
ZV = [0]*1000
U = [0]*1000
V = [0]*1000

for i in range (1000):
    U[i]=R('u%d'%(i))
    V[i]=R('v%d'%(i))

for i in range (40):
    NV[i]=R('n%d'%(i))

for i in range (80):
    KV[i]=R('k%d'%(i))

for i in range (61):
    LV[i]=R('l%d'%(i))

for i in range (61):
    L[i]=LV[i]


for i in range (40):
    N[i]=NV[i]

#gs=60


#for i in range (gs):
    #L[i]=KV[i]

for i in range (80):
    K[i]=KV[i]


for tt in range(0,6):
    tl= R(L[0]+L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= K[ct]


    tn= R(c4+ kt+L[0]+N[0]+N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])
    Z[tt]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+ N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38]  )

    for i in range(60):
        L[i]=L[i+1]
    for i in range(39):
        N[i]=N[i+1]
    L[60]=tl
    N[39]=tn
    print tt,":",Z[tt]
# Out:
# Defining k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, u0, u1, u2, u3, u4, u5, u6, u7, u8, u9, u10, u11, u12, u13, u14, u15, u16, u17, u18, u19, u20, u21, u22, u23, u24, u25, u26, u27, u28, u29, u30, u31, u32, u33, u34, u35, u36, u37, u38, u39, u40, u41, u42, u43, u44, u45, u46, u47, u48, u49, u50, u51, u52, u53, u54, u55, u56, u57, u58, u59, u60, u61, u62, u63, u64, u65, u66, u67, u68, u69, u70, u71, u72, u73, u74, u75, u76, u77, u78, u79, u80, u81, u82, u83, u84, u85, u86, u87, u88, u89, u90, u91, u92, u93, u94, u95, u96, u97, u98, u99, u100, u101, u102, u103, u104, u105, u106, u107, u108, u109, u110, u111, u112, u113, u114, u115, u116, u117, u118, u119, u120, u121, u122, u123, u124, u125, u126, u127, u128, u129, u130, u131, u132, u133, u134, u135, u136, u137, u138, u139, u140, u141, u142, u143, u144, u145, u146, u147, u148, u149, u150, u151, u152, u153, u154, u155, u156, u157, u158, u159, u160, u161, u162, u163, u164, u165, u166, u167, u168, u169, u170, u171, u172, u173, u174, u175, u176, u177, u178, u179, u180, u181, u182, u183, u184, u185, u186, u187, u188, u189, u190, u191, u192, u193, u194, u195, u196, u197, u198, u199, u200, u201, u202, u203, u204, u205, u206, u207, u208, u209, u210, u211, u212, u213, u214, u215, u216, u217, u218, u219, u220, u221, u222, u223, u224, u225, u226, u227, u228, u229, u230, u231, u232,
N = [0]*40
IL = [0]*61
NV = [0]*40
LV = [0]*61
IN = [0]*40
Z = [0]*2000
ZV = [0]*2000
U = [0]*2000
V = [0]*2000

for i in range (1000):
    U[i]=R('u%d'%(i))
    V[i]=R('v%d'%(i))

for i in range (40):
    NV[i]=R('n%d'%(i))

for i in range (61):
    LV[i]=R('l%d'%(i))

for i in range (61):
    IL[i]=ZZ.random_element(2)
    L[i]=IL[i]


for i in range (40):
    IN[i]=ZZ.random_element(2)
    N[i]=IN[i]



for i in range (80):
    K[i]=ZZ.random_element(2)
    KV[i]=R('k%d'%(i))

#forward val

for tt in range(Nr):
    tl= R(L[0]+L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2

    kt= R(K[ct])

    tn= R(L[0]+ c4+ kt+ N[0]+N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])
    Z[tt]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+ N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38]  )

    for i in range(60):
        L[i]=L[i+1]
    for i in range(39):
        N[i]=N[i+1]
    L[60]=tl
    N[39]=tn

#backward val

for i in range (61):
    L[i]=IL[i]


for i in range (40):
    N[i]=IN[i]

tt=Nr-1
while tt >= 0:
    at=Nr-1-tt
    lp=L[60]
    np=N[39]
    j=39
    while(j>0):
        N[j]=N[j-1]
        j=j-1
    j=60
    while(j>0):
        L[j]=L[j-1]
        j=j-1
    tl= R( lp+ L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= K[ct]

    tn= R(L[0]+ c4+ kt+ N[0]+  N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])

    Z[Nr+at]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38] )

    L[0]=R(tl)
    N[0]=R(tn+L[0]+np)
    tt=tt-1

#difference forward val


for i in range (61):
    L[i]=IL[i]

for i in range (40):
    N[i]=IN[i]

L[60] = R(1+L[60])

for tt in range(Nr):
    tl= R(L[0]+L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2

    kt= R(K[ct])

    tn= R(L[0]+ c4+ kt+ N[0]+N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])
    Z[2*Nr+tt]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+ N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38]  )

    for i in range(60):
        L[i]=L[i+1]
    for i in range(39):
        N[i]=N[i+1]
    L[60]=tl
    N[39]=tn

#backward forward val

for i in range (61):
    L[i]=IL[i]

for i in range (40):
    N[i]=IN[i]

L[60] = R(1+L[60])


tt=Nr-1
while tt >= 0:
    at=Nr-1-tt
    lp=L[60]
    np=N[39]
    j=39
    while(j>0):
        N[j]=N[j-1]
        j=j-1
    j=60
    while(j>0):
        L[j]=L[j-1]
        j=j-1
    tl= R( lp+ L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= K[ct]

    tn= R(L[0]+ c4+ kt+ N[0]+  N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])

    Z[3*Nr+at]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38] )

    L[0]=R(tl)
    N[0]=R(tn+L[0]+np)
    tt=tt-1

####variables forward
for i in range (61):
    L[i]=LV[i]

for i in range (gs):
    L[i]=IL[i]

for i in range (40):
    N[i]=NV[i]

#for i in range (40-gsn,40):
   # N[i]=IN[i]

for i in range(40):
    if i ==0 or i==1 or i==4 or i==6 or i==15 or i==17 or i==23 or i==28 or i==38 or i==2 or i==5 or i==39 or i==7 or i==16 or i==18 or i==24 or i==29:
        N[i]=IN[i]

for tt in range(Nr):
    tl= R(L[0]+L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= KV[ct]
    tn= R(L[0]+ c4+ kt+ N[0]+N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])
    ZV[tt]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+ N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38]  )
    A.append(Z[tt]+ZV[tt])
    for i in range(60):
        L[i]=L[i+1]
    for i in range(39):
        N[i]=N[i+1]
    L[60]=U[tt]
    N[39]=V[tt]
    A.append(U[tt]+tl)
    A.append(V[tt]+tn)


####variables backward

for i in range (61):
    L[i]=LV[i]

for i in range (gs):
    L[i]=IL[i]

for i in range (40):
    N[i]=NV[i]

for i in range(40):
    if i==0 or i==1 or i==4 or i==6 or i==15 or i==17 or i==23 or i==28 or i==38 or i==2 or i==5 or i==39 or i==7 or i==16 or i==18 or i==24 or i==29:
        N[i]=IN[i]

tt=Nr-1
while tt >= 0:
    at=Nr-1-tt
    lp=L[60]
    np=N[39]
    j=39
    while(j>0):
        N[j]=N[j-1]
        j=j-1
    j=60
    while(j>0):
        L[j]=L[j-1]
        j=j-1
    tl= R( lp+ L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= K[ct]

    tn= R(L[0]+ c4+ kt+ N[0]+  N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])

    ZV[Nr+at]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38] )
    A.append(Z[Nr+at]+ZV[Nr+at])
    L[0]=U[Nr+at]
    A.append(R(tl+U[Nr+at]))
    N[0]=V[Nr+at]
    A.append(R(tn+L[0]+np+V[Nr+at]))
    tt=tt-1

#for i in range (40-gsn,40):
    #N[i]=IN[i]

#for i in range(40):
    #if i==1 or i==4 or i==6 or i==15 or i==17 or i==23 or i==28 or i==38 or i==2 or i==5 or i==39 or i==7 or i==16 or i==18 or i==24 or i==29:
        #N[i]=IN[i]


####variables forward diff


for i in range (gs):
    L[i]=IL[i]

for i in range (40):
    N[i]=NV[i]

for i in range(40):
    if i==1 or i==4 or i==6 or i==15 or i==17 or i==23 or i==28 or i==38 or i==2 or i==5 or i==39 or i==7 or i==16 or i==18 or i==24 or i==29:
        N[i]=IN[i]

L[60]= 1+L[60]

for tt in range(Nr):
    tl= R(L[0]+L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= KV[ct]
    tn= R(L[0]+ c4+ kt+ N[0]+N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])
    ZV[2*Nr+tt]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+ N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38]  )
    A.append(Z[2*Nr+tt]+ZV[2*Nr+tt])
    for i in range(60):
        L[i]=L[i+1]
    for i in range(39):
        N[i]=N[i+1]
    L[60]=U[2*Nr+tt]
    N[39]=V[2*Nr+tt]
    A.append(U[2*Nr+tt]+tl)
    A.append(V[2*Nr+tt]+tn)

####variables backward diff


for i in range (gs):
    L[i]=IL[i]

for i in range (40):
    N[i]=NV[i]

for i in range(40):
    if i==1 or i==4 or i==6 or i==15 or i==17 or i==23 or i==28 or i==38 or i==2 or i==5 or i==39 or i==7 or i==16 or i==18 or i==24 or i==29:
        N[i]=IN[i]

L[60]=1+L[60]

tt=Nr-1
while tt >= 0:
    at=Nr-1-tt
    lp=L[60]
    np=N[39]
    j=39
    while(j>0):
        N[j]=N[j-1]
        j=j-1
    j=60
    while(j>0):
        L[j]=L[j-1]
        j=j-1
    tl= R( lp+ L[14]+L[20]+L[34]+L[43]+L[54])
    ct= tt%80
    c4= (ct//16)%2
    kt= K[ct]

    tn= R(L[0]+ c4+ kt+ N[0]+  N[13]+N[19]+N[35]+N[39]+ N[2]*N[25] + N[3]*N[5] +N[7]*N[8] + N[14]*N[21] + N[16]*N[18]+ N[22]*N[24] + N[26]*N[32] + N[33]*N[36]*N[37]*N[38] + N[10]*N[11]*N[12]+ N[27]*N[30]*N[31])

    ZV[3*Nr+at]= R(L[30] +N[1]+ N[6]+ N[15]+N[17]+N[23]+N[28]+ N[34]+N[4]*L[6] + L[8]*L[10] +  L[32]*L[17] +  L[19]*L[23] + N[4]*L[32]*N[38] )
    A.append(Z[3*Nr+at]+ZV[3*Nr+at])
    L[0]=U[3*Nr+at]
    A.append(R(tl+U[3*Nr+at]))
    N[0]=V[3*Nr+at]
    A.append(R(tn+L[0]+np+V[3*Nr+at]))
    tt=tt-1

print len(A)
tt=cputime()
I = Ideal(A)

import sage.sat.boolean_polynomials
C= sage.sat.boolean_polynomials.solve(I.gens())
print cputime(tt)

print C


C1=C[0]
S1=[]

for i in range(80):
    a=R.variable(i)
    S1.append(a)

US=[]
for i in range(80):
    if(K[i]!=C1[S1[i]]):
        US.append(i)



# print Set(US).cardinality()
# Out:
# Defining k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, u0, u1, u2, u3, u4, u5, u6, u7, u8, u9, u10, u11, u12, u13, u14, u15, u16, u17, u18, u19, u20, u21, u22, u23, u24, u25, u26, u27, u28, u29, u30, u31, u32, u33, u34, u35, u36, u37, u38, u39, u40, u41, u42, u43, u44, u45, u46, u47, u48, u49, u50, u51, u52, u53, u54, u55, u56, u57, u58, u59, u60, u61, u62, u63, u64, u65, u66, u67, u68, u69, u70, u71, u72, u73, u74, u75, u76, u77, u78, u79, u80, u81, u82, u83, u84, u85, u86, u87, u88, u89, u90, u91, u92, u93, u94, u95, u96, u97, u98, u99, u100, u101, u102, u103, u104, u105, u106, u107, u108, u109, u110, u111, u112, u113, u114, u115, u116, u117, u118, u119, u120, u121, u122, u123, u124, u125, u126, u127, u128, u129, u130, u131, u132, u133, u134, u135, u136, u137, u138, u139, u140, u141, u142, u143, u144, u145, u146, u147, u148, u149, u150, u151, u152, u153, u154, u155, u156, u157, u158, u159, u160, u161, u162, u163, u164, u165, u166, u167, u168, u169, u170, u171, u172, u173, u174, u175, u176, u177, u178, u179, u180, u181, u182, u183, u184, u185, u186, u187, u188, u189, u190, u191, u192, u193, u194, u195, u196, u197, u198, u199, u200, u201, u202, u203, u204, u205, u206, u207, u208, u209, u210, u211, u212, u213, u214, u215, u216, u217, u218, u219, u220, u221, u222, u223, u224, u225, u226, u227, u228, u229, u230, u231, u232, u233, u234, u235, u236, u237, u238, u239, u240, u241, u242, u243, u244, u245, u246, u247, u248, u249, u250, u251, u252, u253, u254, u255, u256, u257, u258, u259, u260, u261, u262, u263, u264, u265, u266, u267, u268, u269, u270, u271, u272, u273, u274, u275, u276, u277, u278, u279, u280, u281, u282, u283, u284, u285, u286, u287, u288, u289, u290, u291, u292, u293, u294, u295, u296, u297, u298, u299, u300, u301, u302, u303, u304, u305, u306, u307, u308, u309, u310, u311, u312, u313, u314, u315, u316, u317, u318, u319, u320, u321, u322, u323, u324, u325, u326, u327, u328, u329, u330, u331, u332, u333, u334, u335, u336, u337, u338, u339, u340, u341, u342, u343, u344, u345, u346, u347, u348, u349, u350, u351, u352, u353, u354, u355, u356, u357, u358, u359, u360, u361, u362, u363, u364, u365, u366, u367, u368, u369, u370, u371, u372, u373, u374, u375, u376, u377, u378, u379, u380, u381, u382, u383, u384, u385, u386, u387, u388, u389, u390, u391, u392, u393, u394, u395, u396, u397, u398, u399, u400, u401, u402, u403, u404, u405, u406, u407, u408, u409, u410, u411, u412, u413, u414, u415, u416, u417, u418, u419, u420, u421, u422, u423, u424, u425, u426, u427, u428, u429, u430, u431, u432, u433, u434, u435, u436, u437, u438, u439, u440, u441, u442, u443, u444, u445, u446, u447, u448, u449, u450, u451, u452, u453, u454, u455, u456, u457, u458, u459, u460, u461, u462, u463, u464, u465, u466, u467, u468, u469, u470, u471, u472, u473, u474, u475, u476, u477, u478, u479, u480, u481, u482, u483, u484, u485, u486, u487, u488, u489, u490, u491, u492, u493, u494, u495, u496, u497, u498, u499, u500, u501, u502, u503, u504, u505, u506, u507, u508, u509, u510, u511, u512, u513, u514, u515, u516, u517, u518, u519, u520, u521, u522, u523, u524, u525, u526, u527, u528, u529, u530, u531, u532, u533, u534, u535, u536, u537, u538, u539, u540, u541, u542, u543, u544, u545, u546, u547, u548, u549, u550, u551, u552, u553, u554, u555, u556, u557, u558, u559, u560, u561, u562, u563, u564, u565, u566, u567, u568, u569, u570, u571, u572, u573, u574, u575, u576, u577, u578, u579, u580, u581, u582, u583, u584, u585, u586, u587, u588, u589, u590, u591, u592, u593, u594, u595, u596, u597, u598, u599, u600, u601, u602, u603, u604, u605, u606, u607, u608, u609, u610, u611, u612, u613, u614, u615, u616, u617, u61 ...
# 3000
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-2-5f9bcd460f98> in <module>()
#     329
#     330 import sage.sat.boolean_polynomials
# --> 331 C= sage.sat.boolean_polynomials.solve(I.gens())
#     332 print cputime(tt)
#     333
#
# /usr/lib/python2.7/dist-packages/sage/sat/boolean_polynomials.pyc in solve(F, converter, solver, n, target_variables, **kwds)
#     165                 solver_kwds[k[2:]] = v
#     166
# --> 167         solver = solver(**solver_kwds)
#     168
#     169     # instantiate the ANF to CNF converter
#
# /usr/lib/python2.7/dist-packages/sage/sat/solvers/cryptominisat.pyc in __init__(self, verbosity, confl_limit, threads)
#      69         except ImportError:
#      70             from sage.misc.package import PackageNotFoundError
# ---> 71             raise PackageNotFoundError("cryptominisat")
#      72         self._solver = Solver(verbose=int(verbosity), confl_limit=int(confl_limit), threads=int(threads))
#      73         self._nvars = 0
#
# PackageNotFoundError: the package u'cryptominisat' was not found. You can install it by running 'sage -i cryptominisat' in a shell

# %%
sage -i cryptominisat
# Out:
#   File "<ipython-input-3-ddfb5807279a>", line 1
#     sage -i cryptominisat
#                         ^
# SyntaxError: invalid syntax

# %%
install-package()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba8c41510359> in <module>()
# ----> 1 install-package()
#
# NameError: name 'install' is not defined
